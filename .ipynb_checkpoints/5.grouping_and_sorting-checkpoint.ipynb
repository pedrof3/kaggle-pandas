# %%
import pandas as pd

# %%
jobs_data = pd.read_csv("datasets/jobs_in_data.csv")

# %%
jobs_data.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
jobs_data.salary_in_usd.describe()
# Out:
# count      9355.000000
# mean     150299.495564
# std       63177.372024
# min       15000.000000
# 25%      105700.000000
# 50%      143000.000000
# 75%      186723.000000
# max      450000.000000
# Name: salary_in_usd, dtype: float64

# %%
jobs_data.experience_level.value_counts()
# Out:
# experience_level
# Senior         6709
# Mid-level      1869
# Entry-level     496
# Executive       281
# Name: count, dtype: int64

# %%
jobs_data.groupby('experience_level').experience_level.count()
# Out:
# experience_level
# Entry-level     496
# Executive       281
# Mid-level      1869
# Senior         6709
# Name: experience_level, dtype: int64

# %%
jobs_data.groupby('experience_level').apply(lambda df: df.loc[df.salary_in_usd.idxmax()])
# Out:
#                   work_year                 job_title  \
# experience_level
# Entry-level            2023         Applied Scientist
# Executive              2021  Principal Data Scientist
# Mid-level              2020        Research Scientist
# Senior                 2020            Data Scientist
#
#                                job_category salary_currency  salary  \
# experience_level
# Entry-level       Data Science and Research             USD  281700
# Executive         Data Science and Research             USD  416000
# Mid-level         Data Science and Research             USD  450000
# Senior            Data Science and Research             USD  412000
#
#                   salary_in_usd employee_residence experience_level  \
# experience_level
# Entry-level              281700      United States      Entry-level
# Executive                416000      United States        Executive
# Mid-level                450000      United States        Mid-level
# ...

# %%
jobs_data.loc[jobs_data.company_location != 'United States']
# Out:
#       work_year                  job_title               job_category  \
# 0          2023       Data DevOps Engineer           Data Engineering
# 13         2023             Data Scientist  Data Science and Research
# 14         2023             Data Scientist  Data Science and Research
# 65         2023  Machine Learning Engineer    Machine Learning and AI
# 66         2023  Machine Learning Engineer    Machine Learning and AI
# ...         ...                        ...                        ...
# 9340       2021              Data Engineer           Data Engineering
# 9345       2020  Machine Learning Engineer    Machine Learning and AI
# 9346       2021   Director of Data Science  Data Science and Research
# 9347       2021             Data Scientist  Data Science and Research
# 9349       2021              Data Engineer           Data Engineering
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
jobs_data.groupby('job_category').salary_in_usd.agg([len, min, max])
# Out:
#                                  len     min     max
# job_category
# BI and Visualization             313   15000  259900
# Cloud and Database                 5  115000  190000
# Data Analysis                   1457   15000  430967
# Data Architecture and Modeling   259   52500  376080
# Data Engineering                2260   18000  385000
# Data Management and Strategy      61   46400  250000
# Data Quality and Operations       55   23753  289120
# Data Science and Research       3014   16000  450000
# Leadership and Management        503   20000  430640
# Machine Learning and AI         1428   15000  423000

# %%
jobs_data.groupby(['job_category', 'work_setting']).salary_in_usd.agg([len, min, max])
# Out:
#                                               len     min     max
# job_category                   work_setting
# BI and Visualization           Hybrid           1   76000   76000
#                                In-person      226   43064  259900
#                                Remote          86   15000  234485
# Cloud and Database             Remote           5  115000  190000
# Data Analysis                  Hybrid          29   20000  125404
#                                In-person      794   15000  430967
#                                Remote         634   17000  323905
# Data Architecture and Modeling Hybrid           2   99703  250000
#                                In-person      124   52500  345600
#                                Remote         133   66000  376080
# Data Engineering               Hybrid          31   18000  161311
#                                In-person     1406   18000  385000
#                                Remote         823   25000  324000
# ...

# %%
jobs_data.groupby('company_location').salary_in_usd.agg([len, min, max])
# Out:
#                        len     min     max
# company_location
# Algeria                  1  100000  100000
# American Samoa           1   50000   50000
# Andorra                  1   50745   50745
# Argentina                5   48000   80000
# Armenia                  1   50000   50000
# ...                    ...     ...     ...
# Turkey                   5   18381   28016
# Ukraine                  6   50000  240000
# United Arab Emirates     3   65000  120000
# United Kingdom         449   30000  430967
# United States         8132   20000  450000
#
# [70 rows x 3 columns]

# %%
countries = jobs_data.groupby('company_location').salary_in_usd.median()

# %%
countries.sort_values()
# Out:
# company_location
# Thailand          15000.0
# Indonesia         15000.0
# Ecuador           16000.0
# Moldova           18000.0
# Honduras          20000.0
#                    ...
# Canada           140000.0
# United States    150000.0
# Japan            164000.0
# Puerto Rico      167500.0
# Qatar            300000.0
# Name: salary_in_usd, Length: 70, dtype: float64

# %%
brazil = jobs_data.loc[(jobs_data.company_location == 'Brazil')]

# %%
brazil.sort_values(by='salary_in_usd')
# Out:
#       work_year                            job_title  \
# 9327       2021             Computer Vision Engineer
# 6857       2023                       Data Scientist
# 9122       2021             Computer Vision Engineer
# 2917       2023                       MLOps Engineer
# 4303       2023  Principal Machine Learning Engineer
# 8217       2022                        Data Engineer
# 8223       2022                           BI Analyst
# 8211       2022                   Analytics Engineer
# 8231       2022                       Data Scientist
# 2972       2023                        Data Engineer
# 2971       2023                        Data Engineer
# 8210       2022                   Analytics Engineer
# 8216       2022                        Data Engineer
# 8222       2022                           BI Analyst
# 8230       2022                       Data Scientist
# 3014       2023                         Head of Data
# 3013       2023                         Head of Data
#
# ...

# %%
brazil.groupby('work_setting').work_setting.count()
# Out:
# work_setting
# Hybrid        1
# In-person     1
# Remote       15
# Name: work_setting, dtype: int64
