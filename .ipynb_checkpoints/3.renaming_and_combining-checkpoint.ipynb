# %%
import pandas as pd

# %%
file = "datasets/VideoGameUsage_Profile.csv"

vg_usage = pd.read_csv(file)

# %% [markdown]
# ## Renaming

# %%
vg_usage
# Out:
#     Age Gender student play_video_game  favorite_game most_played_game  \
# 0    22   Male     Yes             Yes        FIFA 22         FIFA 22
# 1    21   Male     Yes             Yes   Call of Duty     Call of Duty
# 2    23   Male     Yes             Yes  GTA Vice City    GTA Vice City
# 3    23   Male     Yes       sometimes           pubg             pubg
# 4    23   Male     Yes             Yes           pubg             pubg
# ..  ...    ...     ...             ...            ...              ...
# 94   21   Male     Yes             Yes      Minecraft        Minecraft
# 95   23   Male     Yes             Yes      Minecraft        Minecraft
# 96   23   Male     Yes             Yes      Minecraft        Minecraft
# 97   23   Male     Yes             Yes           pubg             pubg
# 98   23   Male     Yes             Yes           pubg             pubg
#
#    reason_of_play_game
# 0          competition
# 1        entertainment
# 2        entertainment
# ...

# %%
vg_usage.rename(columns={'reason_of_play_game' : 'Reason'})
# Out:
#     Age Gender student play_video_game  favorite_game most_played_game  \
# 0    22   Male     Yes             Yes        FIFA 22         FIFA 22
# 1    21   Male     Yes             Yes   Call of Duty     Call of Duty
# 2    23   Male     Yes             Yes  GTA Vice City    GTA Vice City
# 3    23   Male     Yes       sometimes           pubg             pubg
# 4    23   Male     Yes             Yes           pubg             pubg
# ..  ...    ...     ...             ...            ...              ...
# 94   21   Male     Yes             Yes      Minecraft        Minecraft
# 95   23   Male     Yes             Yes      Minecraft        Minecraft
# 96   23   Male     Yes             Yes      Minecraft        Minecraft
# 97   23   Male     Yes             Yes           pubg             pubg
# 98   23   Male     Yes             Yes           pubg             pubg
#
#            Reason
# 0     competition
# 1   entertainment
# 2   entertainment
# 3   entertainment
# 4   entertainment
# ...

# %%
vg_usage.rename(index={0:'zero', 1:'one', 2:'two'})
# Out:
#       Age Gender student play_video_game  favorite_game most_played_game  \
# zero   22   Male     Yes             Yes        FIFA 22         FIFA 22
# one    21   Male     Yes             Yes   Call of Duty     Call of Duty
# two    23   Male     Yes             Yes  GTA Vice City    GTA Vice City
# 3      23   Male     Yes       sometimes           pubg             pubg
# 4      23   Male     Yes             Yes           pubg             pubg
# ...   ...    ...     ...             ...            ...              ...
# 94     21   Male     Yes             Yes      Minecraft        Minecraft
# 95     23   Male     Yes             Yes      Minecraft        Minecraft
# 96     23   Male     Yes             Yes      Minecraft        Minecraft
# 97     23   Male     Yes             Yes           pubg             pubg
# 98     23   Male     Yes             Yes           pubg             pubg
#
#      reason_of_play_game
# zero         competition
# one        entertainment
# ...

# %%
vg_usage.rename_axis('Id', axis='columns')
# Out:
# Id  Age Gender student play_video_game  favorite_game most_played_game  \
# 0    22   Male     Yes             Yes        FIFA 22         FIFA 22
# 1    21   Male     Yes             Yes   Call of Duty     Call of Duty
# 2    23   Male     Yes             Yes  GTA Vice City    GTA Vice City
# 3    23   Male     Yes       sometimes           pubg             pubg
# 4    23   Male     Yes             Yes           pubg             pubg
# ..  ...    ...     ...             ...            ...              ...
# 94   21   Male     Yes             Yes      Minecraft        Minecraft
# 95   23   Male     Yes             Yes      Minecraft        Minecraft
# 96   23   Male     Yes             Yes      Minecraft        Minecraft
# 97   23   Male     Yes             Yes           pubg             pubg
# 98   23   Male     Yes             Yes           pubg             pubg
#
# Id reason_of_play_game
# 0          competition
# 1        entertainment
# 2        entertainment
# ...

# %% [markdown]
# ## Combining

# %%
car_table1 = pd.DataFrame({'Make' : ['Chevrolet', 'Ferrari', 'Porsche'], 'Color' : ['Yellow', 'Red', 'Black']})

# %%
car_table2 = pd.DataFrame({'Make' : ['FIAT', 'Lamborghini', 'Audi'], 'Color' : ['White', 'Green', 'White']})

# %%
pd.concat([car_table1, car_table2])
# Out:
#           Make   Color
# 0    Chevrolet  Yellow
# 1      Ferrari     Red
# 2      Porsche   Black
# 0         FIAT   White
# 1  Lamborghini   Green
# 2         Audi   White
