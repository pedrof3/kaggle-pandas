# %%
import pandas as pd

# %%
grocery_dataset = pd.read_csv("datasets/grocery_dataset.csv")

# %%
grocery_dataset
# Out:
#            Sub Category     Price     Discount  \
# 0     Bakery & Desserts   $56.99   No Discount
# 1     Bakery & Desserts  $159.99   No Discount
# 2     Bakery & Desserts   $44.99   No Discount
# 3     Bakery & Desserts   $39.99   No Discount
# 4     Bakery & Desserts   $59.99   No Discount
# ...                 ...       ...          ...
# 1752             Snacks   $23.99   No Discount
# 1753             Snacks   $49.99   No Discount
# 1754             Snacks   $22.99   No Discount
# 1755             Snacks   $17.49   No Discount
# 1756             Snacks   $21.99   No Discount
#
#                                                Rating  \
# 0      Rated 4.3 out of 5 stars based on 265 reviews.
# 1          Rated 5 out of 5 stars based on 1 reviews.
# 2      Rated 4.1 out of 5 stars based on 441 reviews.
# 3     Rated 4.7 out of 5 stars based on 9459 reviews.
# 4      Rated 4.5 out of 5 stars based on 758 reviews.
# ...                                               ...
# ...

# %%
grocery_dataset.Price
# Out:
# 0        $56.99
# 1       $159.99
# 2        $44.99
# 3        $39.99
# 4        $59.99
#           ...
# 1752     $23.99
# 1753     $49.99
# 1754     $22.99
# 1755     $17.49
# 1756     $21.99
# Name: Price, Length: 1757, dtype: object

# %%
grocery_dataset['Rating']
# Out:
# 0        Rated 4.3 out of 5 stars based on 265 reviews.
# 1            Rated 5 out of 5 stars based on 1 reviews.
# 2        Rated 4.1 out of 5 stars based on 441 reviews.
# 3       Rated 4.7 out of 5 stars based on 9459 reviews.
# 4        Rated 4.5 out of 5 stars based on 758 reviews.
#                              ...
# 1752                                                NaN
# 1753                                                NaN
# 1754                                                NaN
# 1755                                                NaN
# 1756                                                NaN
# Name: Rating, Length: 1757, dtype: object

# %%
grocery_dataset.iloc[0]
# Out:
# Sub Category                                           Bakery & Desserts
# Price                                                            $56.99
# Discount                                                     No Discount
# Rating                    Rated 4.3 out of 5 stars based on 265 reviews.
# Title                  David’s Cookies Mile High Peanut Butter Cake, ...
# Currency                                                               $
# Feature                "10"" Peanut Butter Cake\nCertified Kosher OU-...
# Product Description    A cake the dessert epicure will die for!Our To...
# Name: 0, dtype: object

# %%
grocery_dataset.iloc[: , 0]
# Out:
# 0       Bakery & Desserts
# 1       Bakery & Desserts
# 2       Bakery & Desserts
# 3       Bakery & Desserts
# 4       Bakery & Desserts
#               ...
# 1752               Snacks
# 1753               Snacks
# 1754               Snacks
# 1755               Snacks
# 1756               Snacks
# Name: Sub Category, Length: 1757, dtype: object

# %%
grocery_dataset.iloc[:4, 4]
# Out:
# 0    David’s Cookies Mile High Peanut Butter Cake, ...
# 1    The Cake Bake Shop 8" Round Carrot Cake (16-22...
# 2    St Michel Madeleine, Classic French Sponge Cak...
# 3    David's Cookies Butter Pecan Meltaways 32 oz, ...
# Name: Title, dtype: object

# %%
grocery_dataset.loc[:5, 'Price']
# Out:
# 0     $56.99
# 1    $159.99
# 2     $44.99
# 3     $39.99
# 4     $59.99
# 5     $59.99
# Name: Price, dtype: object

# %%
grocery_dataset.loc[:9, ['Feature', 'Product Description']]
# Out:
#                                              Feature  \
# 0  "10"" Peanut Butter Cake\nCertified Kosher OU-...
# 1  Spiced Carrot Cake with Cream Cheese Frosting ...
# 2  100 count\nIndividually wrapped\nMade in and I...
# 3  Butter Pecan Meltaways\n32 oz 2-Pack\nNo Prese...
# 4  "10" Four Layer Chocolate Cake\nCertified Kosh...
# 5  2-count\nStrawberry Cheesecake\nMango Cheeseca...
# 6  1.3 lb, 6-count\nBaked in, and Imported from, ...
# 7           2-count\nNo Sugar Added\nKosher OU-Dairy
# 8  6 Rocky Road Brownies\n12 Chocoloate Chunk Coo...
# 9  3 Layers of French Valrhona Chocolate Cake   M...
#
#                                  Product Description
# 0  A cake the dessert epicure will die for!Our To...
# 1  Due to the perishable nature of this item, ord...
# 2  Moist and buttery sponge cakes with the tradit...
# 3  These delectable butter pecan meltaways are th...
# 4  A cake the dessert epicure will die for!To the...
# 5  Strawberry Cheesecake: There's only one way to...
# ...

# %%
grocery_dataset.set_index('Sub Category')
# Out:
#                       Price     Discount  \
# Sub Category
# Bakery & Desserts   $56.99   No Discount
# Bakery & Desserts  $159.99   No Discount
# Bakery & Desserts   $44.99   No Discount
# Bakery & Desserts   $39.99   No Discount
# Bakery & Desserts   $59.99   No Discount
# ...                     ...          ...
# Snacks              $23.99   No Discount
# Snacks              $49.99   No Discount
# Snacks              $22.99   No Discount
# Snacks              $17.49   No Discount
# Snacks              $21.99   No Discount
#
#                                                             Rating  \
# Sub Category
# Bakery & Desserts   Rated 4.3 out of 5 stars based on 265 reviews.
# Bakery & Desserts       Rated 5 out of 5 stars based on 1 reviews.
# Bakery & Desserts   Rated 4.1 out of 5 stars based on 441 reviews.
# Bakery & Desserts  Rated 4.7 out of 5 stars based on 9459 reviews.
# Bakery & Desserts   Rated 4.5 out of 5 stars based on 758 reviews.
# ...

# %% [markdown]
# ## Seleção condicional

# %%
grocery_dataset.Discount != 'No Discount'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1752    False
# 1753    False
# 1754    False
# 1755    False
# 1756    False
# Name: Discount, Length: 1757, dtype: bool

# %%
grocery_dataset.loc[grocery_dataset.Discount != 'No Discount']
# Out:
#            Sub Category     Price                      Discount  \
# 33    Beverages & Water   $99.99                  After $30 OFF
# 36    Beverages & Water   $20.99                   After $5 OFF
# 37    Beverages & Water   $19.99                   After $5 OFF
# 38    Beverages & Water   $19.99                   After $5 OFF
# 39    Beverages & Water  $439.99   This item is not returnable.
# ...                 ...       ...                           ...
# 1648             Snacks   $14.99                   After $3 OFF
# 1651             Snacks   $10.49                After $2.50 OFF
# 1662             Snacks   $11.89                After $3.10 OFF
# 1700             Snacks   $11.49                After $3.50 OFF
# 1707             Snacks   $17.99                   After $4 OFF
#
#                                                Rating  \
# 33      Rated 4.5 out of 5 stars based on 28 reviews.
# 36                                                NaN
# ...

# %%
grocery_dataset.loc[(grocery_dataset.Discount != 'No Discount') & (pd.isna(grocery_dataset.Rating) == False)]
# Out:
#                       Sub Category                   Price  \
# 33               Beverages & Water                 $99.99
# 39               Beverages & Water                $439.99
# 46               Beverages & Water                 $89.99
# 185                      Breakfast                 $28.99
# 368              Cleaning Supplies                 $42.99
# 412              Cleaning Supplies                 $17.89
# 503                         Coffee                 $34.99
# 545                           Deli                 $99.99
# 547                           Deli                $199.99
# 549                           Deli                $149.99
# 644                   Gift Baskets                $199.99
# 645                   Gift Baskets                 $49.99
# 651                   Gift Baskets                $149.99
# 657                   Gift Baskets                 $99.99
# 814     Kirkland Signature Grocery                 $15.99
# ...
